# %% [markdown]
# #About Colab notebooks

# %% [markdown]
# ## 1) Get code from github
# <br>
#
# ### Github link: https://github.com/reniew/learning_spoons
#
# * lecture_note
# * codes
#
# IMG 추가 필요 (repo 이미지)
#
#
# ## Get code from github
#
# IMG 추가 필요 (깃헙 연동해서 가져오는 방법)

# %% [markdown]
# ## 2) Mount Google Drive

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive/My\ Drive/Colab\ Notebooks
# Out:
# Day1_1_Colab_Notebook_Setting.ipynb  Day1_4_Session.ipynb
# Day1_2_placeholder.ipynb	     Day1_5_Estimator.ipynb
# Day1_3_tf_data.ipynb		     temp

# %%
# 예시 가져와서 드라이브 넣어서 보여주는 방법

# %% [markdown]
# ## About Machine

# %%
# !nvidia-smi
# Out:
# Wed Aug 21 13:21:44 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.14.0

# %%
import torch
print(torch.__version__)
# Out:
# 1.1.0

# %%
import keras
print(torch.__version__)
# Out:
# 1.1.0
# Using TensorFlow backend.
