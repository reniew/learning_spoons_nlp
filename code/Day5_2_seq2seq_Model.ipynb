# %% [markdown]
# # seq2seq Model

# %%
import os

# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')

# %%
base_path = './gdrive/My Drive/Colab Notebooks'

# %%
data_in_path = base_path + './data_in/'
data_out_path = base_path + './data_out/'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1f6ae1b60afa> in <module>
# ----> 1 data_in_path = base_path + './data_in/'
#       2 data_out_path = base_path + './data_out/'
#
# NameError: name 'base_path' is not defined

# %%
if not os.path.exists(data_in_path):
    os.makedirs(data_in_path)
    
if not os.path.exists(data_out_path):
    os.makedirs(data_out_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0130c3331288> in <module>
# ----> 1 if not os.path.exists(data_in_path):
#       2     os.makedirs(data_in_path)
#       3
#       4 if not os.path.exists(data_out_path):
#       5     os.makedirs(data_out_path)
#
# NameError: name 'data_in_path' is not defined

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from konlpy.tag import Okt

# %%
data = pd.read_csv(data_in_path + 'ChatBotData.csv')

# %%
def tokenize_by_morph(text, okt):
    tokenized_question = []
    tokenized_answer = []
    for question, answer in text:
        tokenized_question.append(okt.morphs(question))
        tokenized_answer.append(okt.morphs(answer))
    
    return tokenized_question, tokenized_answer

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
def build_vocab(word_list, special_tokens = ['<PAD>', '<BOS>', '<EOS>']):
    from collections import Counter

    word_counts = Counter(word_list)
    idx2word = special_tokens + [word for word, _ in word_counts.most_common()]
    word2idx = {word:idx for idx, word in enumerate(idx2word)}

    return idx2word, word2idx

# %%
def text_to_sequence(text_list, word2idx):
    sequence = []
    for text in text_list:
        sequence.append([word2idx[word] for word in text if word in word2idx.keys()])
    
    return sequence

# %%
def sequence_to_text(sequence, vocab):
    return [vocab[idx] for idx in sequence if idx != 0]

# %%
train_data, test_data = train_test_split(data, test_size = 0.1)

okt = Okt()
train_question, train_answer = tokenize_by_morph(train_data[['Q', 'A']].values, okt)
test_question, test_answer = tokenize_by_morph(test_data[['Q', 'A']].values, okt)
# Out:
# /Users/chojunghyun/anaconda3/envs/tensorflow/lib/python3.6/site-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
print('train qeustion')
print(train_question[:3])
print('\ntest qeustion')
print(test_question[:3])
# Out:
# train qeustion
# [['친구', '가', '없어'], ['비트코인', '날림'], ['랜선', '연애', '어떻게', '생각', '해', '?']]
#
# test qeustion
# [['좀', '쉬면서', '애기', '키워야', '할', '듯'], ['공시', '준비', '힘들어'], ['남자친구', '가', '애교', '가', '많아']]

# %%
flatten_word = sum(train_question+train_answer, [])
idx2word, word2idx = build_vocab(sum(train_question+train_answer, []))

# %%
print('flatten word')
print(flatten_word[:5])
print('\nidx2word')
print(idx2word[:5])
print('\nword2idx')
print(word2idx)
# Out:
# flatten word
# ['친구', '가', '없어', '비트코인', '날림']
#
# idx2word
# ['<PAD>', '<BOS>', '<EOS>', '.', '이']
#
# word2idx
# ...

# %%
train_question
# Out:
# [['친구', '가', '없어'],
#  ['비트코인', '날림'],
#  ['랜선', '연애', '어떻게', '생각', '해', '?'],
#  ['혜진',
#   '아',
#   '.',
#   '내',
#   '맘',
#   '이',
#   '너',
#   '에게',
#   '확정',
#   '되기',
#   '전',
#   '에',
#   '날',
#   '떠났어야지'],
#  ['어떻게', '맘', '정리', '를', '할까', '?'],
#  ['이', '사람', '은', '사랑', '이', '참', '쉬운', '가봐', '내', '가', '우습나', '?'],
#  ['졸업식', '가야겠지'],
#  ['헤어진지', '6', '개월', '여', '~'],
#  ['남', '들', '에게', '인정받으려면', '어떻게', '해야', '돼', '?'],
#  ['그녀', '는', '내', '가', '좋아하는', '이', '상황', '을', '즐기는', '것', '같아', '.'],
#  ['결국', '헤어졌어'],
#  ['다시', '재회', '하는', '경우', '는', '기분', '어떨까', '?'],
#  ['동호회', '나가기', '귀찮아'],
#  ['삼겹살', '구워', '먹고', '싶다', '.'],
#  ['썸남', '빼빼로', '줘야', '함', '?'],
#  ['단거', '땡긴다', '.'],
#  ['나', '만', '좋아하는', '것', '같아'],
#  ['옥상', '에', '뭐', '좀', '심어', '볼까'],
#  ['지난', '주말', '부터', '또', '후유증', '이'],
#  ['내', '능력', '이', '너무', '모자라'],
#  ['몸', '이', '아프니까'],
#  ['동거', '8년', '환승', '이별', '.'],
#  ['폰', '자꾸', '보게', '돼'],
#  ['술자리', '에서', '그만', '마시라고', '해주는', '짝녀', '무슨', '뜻', '일까', '요', '?'],
# ...

# %%
index_train_question = text_to_sequence(train_question, word2idx)
index_train_answer = text_to_sequence(train_answer, word2idx)

index_test_question = text_to_sequence(test_question, word2idx)
index_test_answer = text_to_sequence(test_answer, word2idx)

# %%
print('index train question')
print(index_train_question[:3])
print('\nindex test question')
print(index_test_question[:3])
# Out:
# index train question
# [[47, 5, 114], [3291, 6561], [2250, 78, 86, 19, 38, 7]]
#
# index test question
# [[50, 6403, 3455, 35, 216], [2957, 117, 318], [97, 5, 1808, 5, 293]]

# %%
max_length = 30

# %%
pad_train_question = pad_sequences(index_train_question, maxlen = max_length, padding = 'pre')
pad_train_answer = pad_sequences(index_train_answer, maxlen = max_length, padding = 'pre')

pad_test_question = pad_sequences(index_test_question, maxlen = max_length, padding = 'pre')
pad_test_answer = pad_sequences(index_test_answer, maxlen = max_length, padding = 'pre')

# %%
print(pad_train_question.shape)
print(pad_train_answer.shape)

print(pad_test_question.shape)
print(pad_test_answer.shape)
# Out:
# (10640, 30)
# (10640, 30)
# (1183, 30)
# (1183, 30)

# %%
def mapping_fn(question, answer):
    features = {"question": question, 'answer': answer}
    labels = answer
    return features, labels

def train_input_fn(question, answer, epoch, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((question, answer))
    dataset = dataset.shuffle(len(question))
    dataset = dataset.batch(batch_size) 
    dataset = dataset.map(mapping_fn)
    dataset = dataset.repeat(epoch)
    
    return dataset

def test_input_fn(question, answer, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((test_q1, test_q2, test_y))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(mapping_fn)
    
    return dataset

# %%
def seq2seq(features, labels, mode, params):

    TRAIN = mode == tf.estimator.ModeKeys.TRAIN
    EVAL = mode == tf.estimator.ModeKeys.EVAL
    PREDICT = mode == tf.estimator.ModeKeys.PREDICT
    
    embedding = tf.keras.layers.Embedding(params['vocab_size'], params['embedding_dimension'])
    encoder = tf.keras.layers.GRU(params['gru_dimension'], return_state = True)
    decoder = tf.keras.layers.GRU(params['gru_dimension'], return_state = True)
    predicition_layer = tf.keras.layers.Dense(params['vocab_size'])
    
    embedded_question = embedding(features['question']) # (bs, n, d)
    encoder_output, encoder_state = encoder(embedded_question) #(bs, n, d_lstm)
    
    logits = []
    predictions = []
    
    # prepare decoder
    initial_state = encoder_state
    decoder_inputs = tf.ones_like(features['answer'][:, :1]) * params['start_token_index']
    
    embed_decoder_inputs = embedding(decoder_inputs)
    decoder_output, decoder_state = decoder(embed_decoder_inputs, initial_state=initial_state)
    predicted_logits = predicition_layer(decoder_output)
    predicted_token = tf.argmax(predicted_logits, -1)

    predictions.append(predicted_token)
    predicted_token = tf.reshape(predicted_token, (-1, 1))
    logits.append(predicted_logits)
    
    for i in range(params['max_length']-1):
        with tf.variable_scope(f'decoder_{i}_step', reuse=False):

            initial_state = decoder_state
            decoder_inputs = predicted_token

            embed_decoder_inputs = embedding(decoder_inputs)
            decoder_output, decoder_state = decoder(embed_decoder_inputs, initial_state=initial_state)
            predicted_logits = predicition_layer(decoder_output)
            predicted_token = tf.argmax(predicted_logits, -1)

            predictions.append(predicted_token)
            predicted_token = tf.reshape(predicted_token, (-1, 1))
            logits.append(predicted_logits)

    output_logits = tf.stack(logits, 1)
    output_predictions = tf.stack(predictions, 1)
    
    one_hot_label = tf.one_hot(features['answer'], params['vocab_size'])

    loss = tf.losses.softmax_cross_entropy(one_hot_label, output_logits)
    
    global_step = tf.train.get_global_step()
    train_op = tf.train.AdamOptimizer(1e-3).minimize(loss, global_step)

    return tf.estimator.EstimatorSpec(
                        mode=mode,
                        train_op=train_op,
                        loss=loss,
                        predictions={'prediction': predicted_token})

# %%
hyper_params = {'vocab_size': len(word2idx),
                'embedding_dimension': 128,
                'gru_dimension': 128,
                'start_token_index': word2idx['<BOS>'],
                'max_length': 30}

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
from tensorflow.core.protobuf import rewriter_config_pb2
session_config = tf.ConfigProto()
off = rewriter_config_pb2.RewriterConfig.OFF
session_config.graph_options.rewrite_options.arithmetic_optimization = off
run_config = tf.estimator.RunConfig(session_config=session_config)

# %%
estimator = tf.estimator.Estimator(model_fn = seq2seq,
                                   params=hyper_params,
                                   model_dir =data_out+'basic_seq2seq',
                                   config = run_config)
# Out:
# I0928 13:31:53.925467 4642268608 estimator.py:209] Using config: {'_model_dir': './data_out/3', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': graph_options {
#   rewrite_options {
#     arithmetic_optimization: OFF
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc054313828>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
estimator.train(lambda: train_input_fn(pad_train_question, pad_train_answer, 1, 64))
# Out:
# I0928 13:31:56.212563 4642268608 estimator.py:1145] Calling model_fn.
# initial_state: (?, 128)
# decoder_inputs: (?, 1)
# embed_decoder_inputs: (?, 1, 128)
# decoder_output: (?, 128)
# decoder_state: (?, 128)
# predicted_logits: (?, 12148)
# predicted_token: (?,)
# predicted_token: (?, 1)
# (?, 12148)
# step 0
# initial_state: (?, 128)
# decoder_inputs: (?, 1)
# embed_decoder_inputs: (?, 1, 128)
# decoder_output: (?, 128)
# decoder_state: (?, 128)
# predicted_logits: (?, 12148)
# predicted_token: (?,)
# predicted_token: (?, 1)
# step 1
# initial_state: (?, 128)
# decoder_inputs: (?, 1)
# embed_decoder_inputs: (?, 1, 128)
# decoder_output: (?, 128)
# decoder_state: (?, 128)
# predicted_logits: (?, 12148)
# predicted_token: (?,)
# predicted_token: (?, 1)
# step 2
# initial_state: (?, 128)
# decoder_inputs: (?, 1)
# embed_decoder_inputs: (?, 1, 128)
# decoder_output: (?, 128)
# decoder_state: (?, 128)
# predicted_logits: (?, 12148)
# predicted_token: (?,)
# predicted_token: (?, 1)
# ...
